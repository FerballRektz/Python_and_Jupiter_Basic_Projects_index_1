# %% [markdown]
# # DECISION TREE ALGORITHM IMPLEMENTATION IN PYTHON

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report #Import scikit-learn metrics module for accuracy calculation
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("..\\..\\..\\Zeta_export\\Basic\\Basic Decision Tree Implementation\\iris.csv")
df
# Out:
#      SL    SW   PL   PW  CLASS
# 0    5.1  3.5  1.4  0.2      1
# 1    4.9  3.0  1.4  0.2      1
# 2    4.7  3.2  1.3  0.2      1
# 3    4.6  3.1  1.5  0.2      1
# 4    5.0  3.6  1.4  0.2      1
# ..   ...  ...  ...  ...    ...
# 145  6.7  3.0  5.2  2.3      3
# 146  6.3  2.5  5.0  1.9      3
# 147  6.5  3.0  5.2  2.0      3
# 148  6.2  3.4  5.4  2.3      3
# 149  5.9  3.0  5.1  1.8      3
#
# [150 rows x 5 columns]

# %% [markdown]
# ### IMPLEMENTATION

# %%
X = df.iloc[:,:4]
y = df.iloc[:,4]

# %%
X.iloc[:,3]
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
import matplotlib.pyplot as plt
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

plot_tree(clf,rounded= True, filled= True, proportion= True)
# Out:
# [Text(0.4, 0.9, 'x[3] <= 0.8\ngini = 0.665\nsamples = 100.0%\nvalue = [0.343, 0.305, 0.352]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 34.3%\nvalue = [1.0, 0.0, 0.0]'),
#  Text(0.5, 0.7, 'x[3] <= 1.65\ngini = 0.497\nsamples = 65.7%\nvalue = [0.0, 0.464, 0.536]'),
#  Text(0.2, 0.5, 'x[2] <= 5.0\ngini = 0.161\nsamples = 32.4%\nvalue = [0.0, 0.912, 0.088]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 28.6%\nvalue = [0.0, 1.0, 0.0]'),
#  Text(0.3, 0.3, 'x[0] <= 6.05\ngini = 0.375\nsamples = 3.8%\nvalue = [0.0, 0.25, 0.75]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0, 0.0]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 2.9%\nvalue = [0.0, 0.0, 1.0]'),
#  Text(0.8, 0.5, 'x[2] <= 4.85\ngini = 0.056\nsamples = 33.3%\nvalue = [0.0, 0.029, 0.971]'),
#  Text(0.7, 0.3, 'x[1] <= 3.1\ngini = 0.375\nsamples = 3.8%\nvalue = [0.0, 0.25, 0.75]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 2.9%\nvalue = [0.0, 0.0, 1.0]'),
# ...

# %%
plot_tree(clf, feature_names = ["SL","SW","PL","PW"], class_names= ["class_1","class_2","class_3"], rounded= True, filled= True, proportion= True)
# Out:
# [Text(0.4, 0.9, 'PW <= 0.8\ngini = 0.665\nsamples = 100.0%\nvalue = [0.343, 0.305, 0.352]\nclass = class_3'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 34.3%\nvalue = [1.0, 0.0, 0.0]\nclass = class_1'),
#  Text(0.5, 0.7, 'PW <= 1.65\ngini = 0.497\nsamples = 65.7%\nvalue = [0.0, 0.464, 0.536]\nclass = class_3'),
#  Text(0.2, 0.5, 'PL <= 5.0\ngini = 0.161\nsamples = 32.4%\nvalue = [0.0, 0.912, 0.088]\nclass = class_2'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 28.6%\nvalue = [0.0, 1.0, 0.0]\nclass = class_2'),
#  Text(0.3, 0.3, 'SL <= 6.05\ngini = 0.375\nsamples = 3.8%\nvalue = [0.0, 0.25, 0.75]\nclass = class_3'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0, 0.0]\nclass = class_2'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 2.9%\nvalue = [0.0, 0.0, 1.0]\nclass = class_3'),
#  Text(0.8, 0.5, 'PL <= 4.85\ngini = 0.056\nsamples = 33.3%\nvalue = [0.0, 0.029, 0.971]\nclass = class_3'),
# ...

# %%
y_pred = clf.predict(X_test)

print("Confusion Matrix: ",
        confusion_matrix(y_test, y_pred))
print("Accuracy : ",
        accuracy_score(y_test, y_pred)*100)
print("Report : ",
        classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Accuracy :  95.55555555555556
# Report :                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       0.94      0.94      0.94        18
#            3       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
